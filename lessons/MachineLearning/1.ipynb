# %%
conda info --envs
# Out:
# # conda environments:
# #
# base                  *  /opt/conda
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda list
# Out:
# WARNING conda.gateways.disk.delete:unlink_or_rename_to_trash(139): Could not remove or rename /opt/conda/conda-meta/setuptools-51.0.0-py38h06a4308_2.json.  Please remove this file manually (you may need to reboot to free file handles)
# # packages in environment at /opt/conda:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                        main
# _tflow_select             2.3.0                     eigen
# absl-py                   0.11.0             pyhd3eb1b0_1
# aiohttp                   3.6.3            py38h7b6447c_0
# argon2-cffi               20.1.0                   pypi_0    pypi
# astunparse                1.6.3                      py_0
# async-generator           1.10                     pypi_0    pypi
# async-timeout             3.0.1                    py38_0
# attrs                     20.3.0             pyhd3eb1b0_0
# backcall                  0.2.0                    pypi_0    pypi
# ...
